# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
x = []
t =[]
x0 = 100
for i in range(0,60):
    x0 = x0 + np.random.normal(0.05*i,0.1*i)
    if(x0<0):
        x0=0
    x.append(x0)
    t.append(i)

x = np.array(x)
t = np.array(t)


plt.plot(t,x)
